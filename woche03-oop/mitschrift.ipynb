# %%
## Klasse initialisieren
class Fahrzeug:
    kennzeichen = 'AA-A 123'
    baujahr = 0

x = Fahrzeug()
y = Fahrzeug()

x.kennzeichen = "B-AB 123"
x.baujahr = 2015

print(x.kennzeichen)
print(id(fahrzeug_x))

x.__dict__
y.__dict__
## Um auf sich selbst zuzugreifen innerhalb einer Klasse:
## self.attribut

class Fahrzeug :
    def __init__(self, hersteller, baujahr):
        self.hersteller = hersteller
        self.baujahr = baujahr
    def print_info(self):
        print("Hersteller: " + self.hersteller + " Baujahr: " + self.baujahr)
    def set_hersteller(self, hersteller):
        self.hersteller = hersteller
    def set_baujahr(self, baujahr):
        self.baujahr = baujahr

## Ausführen der Klassenmethoden

x = Fahrzeug('VW', 2020) # Attribute notwendig sobald impliziter Konstruktor überschrieben ist durch den expliziten.
x.set_hersteller('Hyundai')
x.set_baujahr(2018)

print(x.__dict__)
print(x)
print(id(x))
## Datenkapselung und Geheimnisprinzip
### Public
ohne Underscore ('variable')
### Protected
mit 1 Underscore ('_variable')
Man kann zwar von außen lesend und schreibend zugreifen, aber der ENtwickler macht damit klar, dass man diese Methode nicht anfassen soll.
### Private
mit 2 Underscore ('__variable')
Sind von außen nicht nutz -, oder lesbar


class EineKlasse():
    def __init(self):
        self.__priv = 'ich bin privat'
        self._prot = 'ich bin geschützt'
        self.pub = 'ich bin öffentlich'
    def get_priv():
        return self.__priv


z = EineKlasse()
z._prot


## Einfachvererbung
class Flugzeug(Fahrzeug):
    def __init__(self, hersteller, baujahr, reichweite):
        self.__reichweite = reichweite 
        super().__init__(hersteller, baujahr)
        def __str__(self):
            return ("Hersteller: " + self.hersteller + " Baujahr: " + self.baujahr + " Reichweite: " + self.reichweite)
class X():
    def hello():
        print("Hallo ich bin X")
class Y():
    super().__init__()
